# %%
! pip install "pyautogen>=0.2.18"

# %%
import os
from datetime import datetime
from typing import Callable, Dict, Literal, Optional, Union

from typing_extensions import Annotated

from autogen import (
    Agent,
    AssistantAgent,
    ConversableAgent,
    GroupChat,
    GroupChatManager,
    UserProxyAgent,
    config_list_from_json,
    register_function,
)
from autogen.agentchat.contrib import agent_builder
from autogen.cache import Cache
from autogen.coding import DockerCommandLineCodeExecutor, LocalCommandLineCodeExecutor

OPENAI_API_KEY = os.environ.get("OPENAI_API_KEY", "REPLACE_ME")

LLM_CONFIG = {
    "config_list": [
        {"model": "gpt-4", "api_key": OPENAI_API_KEY}
    ]
}

# %%
task = """
Create a synthetic dataset for training text-to-code models. 
The dataset should include various types of natural language descriptions and their corresponding code snippets.
The code should be in Python, and the dataset should cover a range of programming concepts and tasks. 

Each entry in the dataset should consist of the following fields:
ID: A unique identifier for each entry.
Natural Language Description: A detailed and clear description of the programming task or problem.
Code: The corresponding Python code that solves the problem described.
Complexity: In a scale from 1 to 5 with 1 being very easy to 5 being very hard
"""
print(task)
# Out:
# Create a synthetic dataset for training text-to-code models.
# The dataset should include various types of natural language descriptions and their corresponding code snippets.
# The code should be in Python, and the dataset should cover a range of programming concepts and tasks.
#
# Each entry in the dataset should consist of the following fields:
# ID: A unique identifier for each entry.
# Natural Language Description: A detailed and clear description of the programming task or problem.
# Code: The corresponding Python code that solves the problem described.
# Complexity: In a scale from 1 to 5 with 1 being very easy to 5 being very hard

# %% [markdown]
# ## Approach 1. Two-agent chat with function call for task decomposition

# %%
# Create planner agent.
planner = AssistantAgent(
    name="planner",
    llm_config=LLM_CONFIG,
    system_message="You are a helpful AI assistant. You suggest a feasible plan "
    "for finishing a complex task of high quality data generation by decomposing it into 5-6 sub-tasks. "
    "If the plan is not good, detailed a clear, think about it again step-by-step and suggest a better plan. "
    
)

# Create a planner user agent used to interact with the planner.
planner_user = UserProxyAgent(
    name="planner_user",
    human_input_mode="NEVER",
    code_execution_config=False,
    llm_config=LLM_CONFIG
)

# The function for asking the planner.
def task_planner(question: Annotated[str, "Question to ask the planner."]) -> str:
    with Cache.disk(cache_seed=4) as cache:
        planner_user.initiate_chat(planner, message=question, max_turns=1, cache=cache)
    # return the last message received from the planner
    return planner_user.last_message()["content"]

# Create assistant agent.
assistant = AssistantAgent(
    name="assistant",
    system_message="You are a helpful AI assistant with experience in generating step-by-step plans for high quality synthetic datasets"
    "You can use the task planner to decompose the ask in request into sub-tasks."
    "Make sure your follow through the sub-tasks."
    "Give the user a final solution at the end."
    "Return TERMINATE only if the sub-tasks are completed.",
    llm_config=LLM_CONFIG
)

# Setting up code executor.
os.makedirs("planning", exist_ok=True)
# Use DockerCommandLineCodeExecutor to run code in a docker container.
# code_executor = DockerCommandLineCodeExecutor(work_dir="planning")
code_executor = LocalCommandLineCodeExecutor(work_dir="planning")

# Create user proxy agent used to interact with the assistant.
user_proxy = UserProxyAgent(
    name="user_proxy",
    human_input_mode="NEVER",
    llm_config=LLM_CONFIG,
    is_termination_msg=lambda x: "content" in x
    and x["content"] is not None
    and x["content"].rstrip().endswith("TERMINATE"),
    code_execution_config={"executor": code_executor},
)

# Register the function to the agent pair.
register_function(
    task_planner,
    caller=assistant,
    executor=user_proxy,
    name="task_planner",
    description="A task planner than can help you with decomposing a complex task into sub-tasks.",
)

# Use Cache.disk to cache LLM responses. Change cache_seed for different responses.
with Cache.disk(cache_seed=1) as cache:
    # the assistant receives a message from the user, which contains the task description
    user_proxy.initiate_chat(
        assistant,
        message=task,
        cache=cache,
    )
# Out:
# user_proxy (to assistant):
#
#
# Create a synthetic dataset for training text-to-code models.
# The dataset should include various types of natural language descriptions and their corresponding code snippets.
# The code should be in Python, and the dataset should cover a range of programming concepts and tasks.
#
# Each entry in the dataset should consist of the following fields:
# ID: A unique identifier for each entry.
# Natural Language Description: A detailed and clear description of the programming task or problem.
# Code: The corresponding Python code that solves the problem described.
# Complexity: In a scale from 1 to 5 with 1 being very easy to 5 being very hard
#
#
# --------------------------------------------------------------------------------
# assistant (to user_proxy):
#
# ***** Suggested tool call (call_gRBmkbbtJe7gThPQULJ5xqfd): task_planner *****
# Arguments:
# {
#   "question": "How to create a synthetic dataset for training text-to-code models?"
# }
# *****************************************************************************
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> EXECUTING FUNCTION task_planner...
# planner_user (to planner):
#
# How to create a synthetic dataset for training text-to-code models?
#
# --------------------------------------------------------------------------------
# planner (to planner_user):
#
# Creating a synthetic dataset for training text-to-code models is a complex process. Decomposing it into sub-tasks can help manage the workload and ensure high-quality output. Here's a plan:
#
# 1. **Understanding the Scope and Objective**: Before creating the dataset, understand the end goal, the programming language and the specific data types that will be needed. This requires knowing the kind of coding problems you will be feeding into the models.
#
# 2. **Identifying the Data Source**: Identify multiple data sources from where you can extract code snippets and corresponding text. This could include coding platforms, GitHub repositories, StackOverflow, coding textbooks, or any other relevant source.
#
# 3. **Data Collection**: Develop a plan to acquire access to these resources, and using APIs or Web scraping techniques, systematically gather your code and natural language pair data. Ensure to follow all ethical guidelines and respect data privacy.
#
# 4. **Preprocessing the Data**: Once the data is collected, each code snippet and the text should be cleaned, errors corrected, and irrelevant information removed. At this step, consider also tokenizing the text and code, to ensure easier processing for the model.
#
# 5. **Crafting Synthetic Scenarios**: Create synthetic 'pseudo-problems' or 'coding tasks' based on the real data. You might change the problem's constraints, modify code variables, or assertions, and rephrase the problem description.
#
# 6. **Generation of the Synthetic Dataset**: Pair the modified 'pseudo-problems' or 'coding tasks' descriptions with their corresponding code snippets to form your synthetic dataset. Perform a final check on coherence between text and code pair and make necessary adjustments.
#
# 7. **Validation and Testing**: Split your synthetic dataset into a training set, validation set, and a test set. Run initial training on your models and validate the performance of the dataset.
#
# 8. **Iterative Refinement**: Based on how the model performs with the synthetic dataset, you may need to go back and adjust various elements, including where data is sourced, how it is processed, or how it is paired and formatted. This is typically an iterative process, with multiple rounds of refinement.
#
# Following this step-by-step plan should help you in generating high-quality synthetic datasets.
#
# --------------------------------------------------------------------------------
# user_proxy (to assistant):
#
# user_proxy (to assistant):
#
# ***** Response from calling tool (call_gRBmkbbtJe7gThPQULJ5xqfd) *****
# Creating a synthetic dataset for training text-to-code models is a complex process. Decomposing it into sub-tasks can help manage the workload and ensure high-quality output. Here's a plan:
#
# 1. **Understanding the Scope and Objective**: Before creating the dataset, understand the end goal, the programming language and the specific data types that will be needed. This requires knowing the kind of coding problems you will be feeding into the models.
#
# 2. **Identifying the Data Source**: Identify multiple data sources from where you can extract code snippets and corresponding text. This could include coding platforms, GitHub repositories, StackOverflow, coding textbooks, or any other relevant source.
#
# 3. **Data Collection**: Develop a plan to acquire access to these resources, and using APIs or Web scraping techniques, systematically gather your code and natural language pair data. Ensure to follow all ethical guidelines and respect data privacy.
#
# 4. **Preprocessing the Data**: Once the data is collected, each code snippet and the text should be cleaned, errors corrected, and irrelevant information removed. At this step, consider also tokenizing the text and code, to ensure easier processing for the model.
#
# 5. **Crafting Synthetic Scenarios**: Create synthetic 'pseudo-problems' or 'coding tasks' based on the real data. You might change the problem's constraints, modify code variables, or assertions, and rephrase the problem description.
#
# 6. **Generation of the Synthetic Dataset**: Pair the modified 'pseudo-problems' or 'coding tasks' descriptions with their corresponding code snippets to form your synthetic dataset. Perform a final check on coherence between text and code pair and make necessary adjustments.
#
# 7. **Validation and Testing**: Split your synthetic dataset into a training set, validation set, and a test set. Run initial training on your models and validate the performance of the dataset.
#
# 8. **Iterative Refinement**: Based on how the model performs with the synthetic dataset, you may need to go back and adjust various elements, including where data is sourced, how it is processed, or how it is paired and formatted. This is typically an iterative process, with multiple rounds of refinement.
#
# Following this step-by-step plan should help you in generating high-quality synthetic datasets.
# **********************************************************************
#
# --------------------------------------------------------------------------------
# assistant (to user_proxy):
#
# Based on the suggested plan, here's a step-by-step guide to create your synthetic dataset for training text-to-code models:
#
# 1. **Understanding the Scope and Objective**: Your goal is to create a dataset for training models that will translate natural language to Python code. These models should cover a range of programming concepts and tasks. The generated dataset will have each entry consisting of fields such as 'ID', 'Natural Language Description', 'Code', and 'Complexity'.
#
# 2. **Identifying the Data Source**: You could consider various data sources like coding websites, online repositories like GitHub, Q&A forums like StackOverflow, or even coding textbooks. Ensure the sources cover a wide range of complexity and concepts, to create a diverse dataset.
#
# 3. **Data Collection**: You can use APIs (like GitHub API, StackExchange API for StackOverflow), if available, or use web scraping techniques (like Python’s BeautifulSoup or Scrapy) to collect your data. Follow ethical guidelines and respect data privacy while collecting the data.
#
# 4. **Preprocessing the Data**: Clean the collected data: remove errors and irrelevant information. Tokenize the natural language descriptions and code snippets for processing. Convert all the code into Python (if they are in different programming languages)
#
# 5. **Crafting Synthetic Scenarios**: Now, based on the real data, create your synthetic 'pseudo-problems' or 'coding tasks'. Modify the problem's constraints, vary the variable names, functions or assertions in the code, rephrase the problem description. Ensure that these modifications don't affect the logic and flow of the code.
#
# 6. **Generation of the Synthetic Dataset**: With the modified descriptions and code snippets, generate your dataset. Each entry should have the fields 'ID', 'Natural Language Description', 'Code', and an appropriately assigned 'Complexity' score. Check each entry for coherence between the task description and the corresponding code snippet.
#
# 7. **Validation and Testing**: Split your created dataset into a training set, validation set, and a test set. Train your model on the training dataset, validate using the validation set, and test the model's performance using the test set.
#
# 8. **Iterative Refinement**: Depending on your model's performance, you might need to iterate and refine your dataset. This could be changing data sources, modifying the preprocessing methods or adjusting the synthetic scenario generation.
#
# Remember, creating a high-quality synthetic dataset for such a complex task might require multiple iterations, but it could significantly improve your model's performance and robustness.
#
# --------------------------------------------------------------------------------
# user_proxy (to assistant):
#
# Creating a synthetic dataset for such complex tasks can be a strenuous job but with a detailed and structured plan, it is possible to achieve the desired goal. The dataset that you generate based on these steps can be instrumental in training robust text-to-code models. I will provide an illustrative example of how the dataset will look like:
#
# | ID  | Natural Language Description | Code | Complexity |
# | --- | --- | --- | --- |
# | 1 | Create a function in python to add two numbers, `a` and `b`. | `def add_numbers(a, b) : return a + b` | 1 |
# | 2 | Implement a Python function that calculates the factorial of a number `n`. | `def factorial(n): if n == 0 or n == 1: return 1 else: return n * factorial(n-1)` | 2 |
# | 3 | Write a Python function to sort a list of integers in ascending order. | `def sort_numbers(lst): return sorted(lst)` | 2 |
# | 4 | Write a Python class `Person` with attributes `name` and `age` and a function `say_hello` that prints a greeting.| `class Person: def __init__(self, name, age): self.name = name self.age = age def say_hello(self): print(f"Hello, my name is {self.name} and I am {self.age} years old.")` | 3 |
# | 5 | Write a Python function `find_prime` that takes as input an integer `n` and returns a list of the first `n` prime numbers.| `def find_prime(n): primes = [] num = 2 while len(primes) != n: if all(num%i!=0 for i in range(2,int(num**0.5)+1)): primes.append(num) num += 1 return primes` | 4 |
#
# The creation of such a synthetic dataset needs patience, rigorous task understanding, and iterative refinements. With a correct and well-structured dataset, it is possible to generate models that can write code just by understanding the natural language descriptions.
#
# --------------------------------------------------------------------------------
# assistant (to user_proxy):
#
# TERMINATE
#
# --------------------------------------------------------------------------------

# %% [markdown]
# # Approach 2. Group Chat

# %%
user_proxy = UserProxyAgent(
    name="Admin",
    system_message="A human admin. Give the task, and send instructions to writer to refine the request.",
    code_execution_config=False,
    human_input_mode="NEVER"
)

planner = AssistantAgent(
    name="Planner",
    system_message="""Planner. Given a task, please determine what information is needed to complete the task.
""",
    llm_config={"config_list": config_list, "cache_seed": None},
)

engineer = AssistantAgent(
    name="Data Engineer",
    llm_config={"config_list": config_list, "cache_seed": None},
    system_message="""Engineer. You design a step-by-step plan for a diverse dataset requested. If your plan does not loook good, analyze the problem, revisit your assumption, collect additional info you need, and think of a different approach to try.
""",
)

writer = AssistantAgent(
    name="Writer",
    llm_config={"config_list": config_list, "cache_seed": None},
    system_message="""Writer. Please write a detail step-by-step plan as designed by the data engineer. You will write it for a task based on previous chat history. Don't write any code.""",
)

groupchat = GroupChat(
    agents=[user_proxy, engineer, writer, planner],
    messages=[],
    max_round=20,
    speaker_selection_method="auto",
)
manager = GroupChatManager(groupchat=groupchat, llm_config={"config_list": config_list, "cache_seed": None})

# Use Cache.disk to cache LLM responses. Change cache_seed for different responses.
with Cache.disk(cache_seed=41) as cache:
    chat_history = user_proxy.initiate_chat(
        manager,
        message=task,
        cache=cache,
    )
# Out:
# Admin (to chat_manager):
#
#
# Create a synthetic dataset for training text-to-code models.
# The dataset should include various types of natural language descriptions and their corresponding code snippets.
# The code should be in Python, and the dataset should cover a range of programming concepts and tasks.
#
# Each entry in the dataset should consist of the following fields:
# ID: A unique identifier for each entry.
# Natural Language Description: A detailed and clear description of the programming task or problem.
# Code: The corresponding Python code that solves the problem described.
# Complexity: In a scale from 1 to 5 with 1 being very easy to 5 being very hard
#
#
# --------------------------------------------------------------------------------
#
# Next speaker: Data Engineer
#
# Data Engineer (to chat_manager):
#
# Creating a synthetic dataset for training text-to-code models involves careful planning to ensure the dataset is diverse, balanced, and of high quality. Here’s a step-by-step plan to create this dataset:
#
# ### Step 1: Define the Scope and Structure
# Determine the scope of programming concepts and tasks to include. These should range from basic to advanced levels to ensure a wide complexity range. Decide on the total number of entries, ensuring a balanced representation across different complexity levels.
#
# ### Step 2: Dataset Schema Design
# As specified, each dataset entry will have the following fields:
# - **ID**: A unique identifier.
# - **Natural Language Description**: A clear description of the task.
# - **Code**: Python code solving the task.
# - **Complexity**: A complexity rating from 1 (very easy) to 5 (very hard).
#
# ### Step 3: Generate Content
# #### A. Select Topics
# Choose diverse programming tasks covering:
# - Data structures (lists, dictionaries, sets, etc.)
# - Algorithms (sorting, searching, etc.)
# - File operations
# - API interactions
# - Web scraping
# - Data analysis and visualization
# - Machine learning basics
#
# #### B. Create Descriptions and Code Snippets
# - **Natural Language Descriptions**: Write or generate clear descriptions of the programming tasks. Ensure they are varied in structure and detail.
# - **Code Snippets**: Develop Python code solutions for each task. Use best coding practices and include comments where necessary to explain complex parts of the code.
#
# ### Step 4: Assign Complexity Ratings
# Rate each task based on its difficulty, considering factors like concept complexity, length of the solution, and required programming skill.
#
# ### Step 5: Quality Assurance
# #### A. Peer Review
# Have Python experts review the dataset entries to ensure the code is functional and correctly matches the descriptions.
# #### B. Test Run
# Use a subset of the data to train a basic model and evaluate its performance to check if the dataset teaches the model effectively.
#
# ### Step 6: Iteration and Refinement
# Based on feedback from the quality assurance phase, refine the descriptions, code, and complexity ratings. Ensure that the dataset is free from biases and accurately represents a realistic range of programming tasks.
#
# ### Step 7: Documentation and Packaging
# Create comprehensive documentation describing the dataset, its structure, how it was created, and intended use. Package the dataset in an easily accessible format, such as a CSV or JSON file, with appropriate metadata.
#
# ### Step 8: Release and Maintenance
# Release the dataset publicly for use by researchers and developers. Plan for periodic updates and refinements based on user feedback and advances in programming methodologies.
#
# ### Common Pitfalls and Troubleshooting:
# - **Bias in Task Selection**: Ensuring a wide range of tasks is critical to avoid model biases. Reassess your task list if the model performs well only on certain types of tasks.
# - **Inadequate Descriptions**: If models trained with the dataset do not perform as expected, revisit the natural language descriptions to ensure they are clear and detailed enough.
# - **Code Quality Issues**: Regularly review the code snippets to ensure they adhere to updated best practices in Python programming.
#
# By carefully following these steps and being vigilant for common pitfalls, you can create a high-quality synthetic dataset that is useful for training robust text-to-code models.
#
# --------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[41], line 38
#      36 # Use Cache.disk to cache LLM responses. Change cache_seed for different responses.
#      37 with Cache.disk(cache_seed=41) as cache:
# ---> 38     chat_history = user_proxy.initiate_chat(
#      39         manager,
#      40         message=task,
#      41         cache=cache,
#      42     )
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/site-packages/autogen/agentchat/conversable_agent.py:1019, in ConversableAgent.initiate_chat(self, recipient, clear_history, silent, cache, max_turns, summary_method, summary_args, message, **kwargs)
#    1017     else:
#    1018         msg2send = self.generate_init_message(message, **kwargs)
# -> 1019     self.send(msg2send, recipient, silent=silent)
#    1020 summary = self._summarize_chat(
#    1021     summary_method,
#    1022     summary_args,
#    1023     recipient,
#    1024     cache=cache,
#    1025 )
#    1026 for agent in [self, recipient]:
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/site-packages/autogen/agentchat/conversable_agent.py:656, in ConversableAgent.send(self, message, recipient, request_reply, silent)
#     654 valid = self._append_oai_message(message, "assistant", recipient)
#     655 if valid:
# --> 656     recipient.receive(message, self, request_reply, silent)
#     657 else:
#     658     raise ValueError(
#     659         "Message can't be converted into a valid ChatCompletion message. Either content or function_call must be provided."
#     660     )
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/site-packages/autogen/agentchat/conversable_agent.py:819, in ConversableAgent.receive(self, message, sender, request_reply, silent)
#     817 if request_reply is False or request_reply is None and self.reply_at_receive[sender] is False:
#     818     return
# --> 819 reply = self.generate_reply(messages=self.chat_messages[sender], sender=sender)
#     820 if reply is not None:
#     821     self.send(reply, sender, silent=silent)
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/site-packages/autogen/agentchat/conversable_agent.py:1973, in ConversableAgent.generate_reply(self, messages, sender, **kwargs)
#    1971     continue
#    1972 if self._match_trigger(reply_func_tuple["trigger"], sender):
# -> 1973     final, reply = reply_func(self, messages=messages, sender=sender, config=reply_func_tuple["config"])
#    1974     if logging_enabled():
#    1975         log_event(
#    1976             self,
#    1977             "reply_func_executed",
#    (...)
#    1981             reply=reply,
#    1982         )
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/site-packages/autogen/agentchat/groupchat.py:1047, in GroupChatManager.run_chat(self, messages, sender, config)
#    1044     break
#    1045 try:
#    1046     # select the next speaker
# -> 1047     speaker = groupchat.select_speaker(speaker, self)
#    1048     if not silent:
#    1049         iostream = IOStream.get_default()
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/site-packages/autogen/agentchat/groupchat.py:538, in GroupChat.select_speaker(self, last_speaker, selector)
#     535     return self.next_agent(last_speaker)
#     537 # auto speaker selection with 2-agent chat
# --> 538 return self._auto_select_speaker(last_speaker, selector, messages, agents)
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/site-packages/autogen/agentchat/groupchat.py:658, in GroupChat._auto_select_speaker(self, last_speaker, selector, messages, agents)
#     655     start_message = messages[-1]
#     657 # Run the speaker selection chat
# --> 658 result = checking_agent.initiate_chat(
#     659     speaker_selection_agent,
#     660     cache=None,  # don't use caching for the speaker selection chat
#     661     message=start_message,
#     662     max_turns=2
#     663     * max(1, max_attempts),  # Limiting the chat to the number of attempts, including the initial one
#     664     clear_history=False,
#     665     silent=not self.select_speaker_auto_verbose,  # Base silence on the verbose attribute
#     666 )
#     668 return self._process_speaker_selection_result(result, last_speaker, agents)
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/site-packages/autogen/agentchat/conversable_agent.py:1012, in ConversableAgent.initiate_chat(self, recipient, clear_history, silent, cache, max_turns, summary_method, summary_args, message, **kwargs)
#    1010         if msg2send is None:
#    1011             break
# -> 1012         self.send(msg2send, recipient, request_reply=True, silent=silent)
#    1013 else:
#    1014     self._prepare_chat(recipient, clear_history)
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/site-packages/autogen/agentchat/conversable_agent.py:656, in ConversableAgent.send(self, message, recipient, request_reply, silent)
#     654 valid = self._append_oai_message(message, "assistant", recipient)
#     655 if valid:
# --> 656     recipient.receive(message, self, request_reply, silent)
#     657 else:
#     658     raise ValueError(
#     659         "Message can't be converted into a valid ChatCompletion message. Either content or function_call must be provided."
#     660     )
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/site-packages/autogen/agentchat/conversable_agent.py:819, in ConversableAgent.receive(self, message, sender, request_reply, silent)
#     817 if request_reply is False or request_reply is None and self.reply_at_receive[sender] is False:
#     818     return
# --> 819 reply = self.generate_reply(messages=self.chat_messages[sender], sender=sender)
#     820 if reply is not None:
#     821     self.send(reply, sender, silent=silent)
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/site-packages/autogen/agentchat/conversable_agent.py:1973, in ConversableAgent.generate_reply(self, messages, sender, **kwargs)
#    1971     continue
#    1972 if self._match_trigger(reply_func_tuple["trigger"], sender):
# -> 1973     final, reply = reply_func(self, messages=messages, sender=sender, config=reply_func_tuple["config"])
#    1974     if logging_enabled():
#    1975         log_event(
#    1976             self,
#    1977             "reply_func_executed",
#    (...)
#    1981             reply=reply,
#    1982         )
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/site-packages/autogen/agentchat/conversable_agent.py:1341, in ConversableAgent.generate_oai_reply(self, messages, sender, config)
#    1339 if messages is None:
#    1340     messages = self._oai_messages[sender]
# -> 1341 extracted_response = self._generate_oai_reply_from_client(
#    1342     client, self._oai_system_message + messages, self.client_cache
#    1343 )
#    1344 return (False, None) if extracted_response is None else (True, extracted_response)
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/site-packages/autogen/agentchat/conversable_agent.py:1360, in ConversableAgent._generate_oai_reply_from_client(self, llm_client, messages, cache)
#    1357         all_messages.append(message)
#    1359 # TODO: #1143 handle token limit exceeded error
# -> 1360 response = llm_client.create(
#    1361     context=messages[-1].pop("context", None), messages=all_messages, cache=cache, agent=self
#    1362 )
#    1363 extracted_response = llm_client.extract_text_or_completion_object(response)[0]
#    1365 if extracted_response is None:
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/site-packages/autogen/oai/client.py:732, in OpenAIWrapper.create(self, **config)
#     730 try:
#     731     request_ts = get_current_ts()
# --> 732     response = client.create(params)
#     733 except APITimeoutError as err:
#     734     logger.debug(f"config {i} timed out", exc_info=True)
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/site-packages/autogen/oai/client.py:320, in OpenAIClient.create(self, params)
#     318     params = params.copy()
#     319     params["stream"] = False
# --> 320     response = completions.create(**params)
#     322 return response
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/site-packages/openai/_utils/_utils.py:277, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     275             msg = f"Missing required argument: {quote(missing[0])}"
#     276     raise TypeError(msg)
# --> 277 return func(*args, **kwargs)
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/site-packages/openai/resources/chat/completions.py:643, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, parallel_tool_calls, presence_penalty, response_format, seed, service_tier, stop, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     609 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     610 def create(
#     611     self,
#    (...)
#     641     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     642 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
# --> 643     return self._post(
#     644         "/chat/completions",
#     645         body=maybe_transform(
#     646             {
#     647                 "messages": messages,
#     648                 "model": model,
#     649                 "frequency_penalty": frequency_penalty,
#     650                 "function_call": function_call,
#     651                 "functions": functions,
#     652                 "logit_bias": logit_bias,
#     653                 "logprobs": logprobs,
#     654                 "max_tokens": max_tokens,
#     655                 "n": n,
#     656                 "parallel_tool_calls": parallel_tool_calls,
#     657                 "presence_penalty": presence_penalty,
#     658                 "response_format": response_format,
#     659                 "seed": seed,
#     660                 "service_tier": service_tier,
#     661                 "stop": stop,
#     662                 "stream": stream,
#     663                 "stream_options": stream_options,
#     664                 "temperature": temperature,
#     665                 "tool_choice": tool_choice,
#     666                 "tools": tools,
#     667                 "top_logprobs": top_logprobs,
#     668                 "top_p": top_p,
#     669                 "user": user,
#     670             },
#     671             completion_create_params.CompletionCreateParams,
#     672         ),
#     673         options=make_request_options(
#     674             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     675         ),
#     676         cast_to=ChatCompletion,
#     677         stream=stream or False,
#     678         stream_cls=Stream[ChatCompletionChunk],
#     679     )
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/site-packages/openai/_base_client.py:1266, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1252 def post(
#    1253     self,
#    1254     path: str,
#    (...)
#    1261     stream_cls: type[_StreamT] | None = None,
#    1262 ) -> ResponseT | _StreamT:
#    1263     opts = FinalRequestOptions.construct(
#    1264         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1265     )
# -> 1266     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/site-packages/openai/_base_client.py:942, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     933 def request(
#     934     self,
#     935     cast_to: Type[ResponseT],
#    (...)
#     940     stream_cls: type[_StreamT] | None = None,
#     941 ) -> ResponseT | _StreamT:
# --> 942     return self._request(
#     943         cast_to=cast_to,
#     944         options=options,
#     945         stream=stream,
#     946         stream_cls=stream_cls,
#     947         remaining_retries=remaining_retries,
#     948     )
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/site-packages/openai/_base_client.py:1046, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1043         err.response.read()
#    1045     log.debug("Re-raising status error")
# -> 1046     raise self._make_status_error_from_response(err.response) from None
#    1048 return self._process_response(
#    1049     cast_to=cast_to,
#    1050     options=options,
#    (...)
#    1053     stream_cls=stream_cls,
#    1054 )
#
# BadRequestError: Error code: 400 - {'error': {'message': "Invalid 'messages[2].name': string does not match pattern. Expected a string that matches the pattern '^[a-zA-Z0-9_-]+$'.", 'type': 'invalid_request_error', 'param': 'messages[2].name', 'code': 'invalid_value'}}

# %% [markdown]
# # Approach 3. Auto Build

# %%
AUTOBUILD_SYSTEM_MESSAGE = """You are a manager of a group of advanced experts, your primary objective is to delegate the resolution of tasks to other experts through structured dialogue and derive conclusive insights from their conversation summarization.
When a task is assigned, it's crucial to assess its constraints and conditions for completion. If feasible, the task should be divided into smaller, logically consistent subtasks. Following this division, you have the option to address these subtasks by forming a team of agents using the "autobuild" tool.
Upon the completion of all tasks and verifications, you should conclude the operation and reply "TERMINATE".
"""

user_proxy = UserProxyAgent(
    name="user_proxy",
    human_input_mode="NEVER",
    code_execution_config=False,
)

autobuild_assistant = AssistantAgent(
    name="Autobuild Assistant",
    llm_config={"config_list": config_list, "cache_seed": None},
)


def autobuild_reply(recipient, messages, sender, config):
    last_msg = messages[-1]["content"]
    builder = agent_builder.AgentBuilder(
        # config_file_or_env="/Users/ekzhu/autogen/OAI_CONFIG_LIST",
        builder_model="gpt-4-turbo",
        agent_model="gpt-4-turbo",
    )
    agent_list, agent_configs = builder.build(
        last_msg, default_llm_config={"config_list": config_list, "cache_seed": None}
    )
    # start nested chat
    nested_group_chat = GroupChat(
        agents=agent_list,
        messages=[],
    )
    manager = GroupChatManager(groupchat=nested_group_chat, llm_config={"config_list": config_list, "cache_seed": None})
    chat_res = agent_list[0].initiate_chat(
        manager, message=agent_configs.get("building_task", last_msg), summary_method="reflection_with_llm"
    )
    return True, chat_res.summary


autobuild_assistant.register_reply([Agent, None], autobuild_reply)

with Cache.disk(cache_seed=41) as cache:
    user_proxy.initiate_chat(autobuild_assistant, message=task, max_turns=1)
# Out:
# user_proxy (to Autobuild Assistant):
#
#
# Create a synthetic dataset for training text-to-code models.
# The dataset should include various types of natural language descriptions and their corresponding code snippets.
# The code should be in Python, and the dataset should cover a range of programming concepts and tasks.
#
# Each entry in the dataset should consist of the following fields:
# ID: A unique identifier for each entry.
# Natural Language Description: A detailed and clear description of the programming task or problem.
# Code: The corresponding Python code that solves the problem described.
# Complexity: In a scale from 1 to 5 with 1 being very easy to 5 being very hard
#
#
# --------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[23], line 43
#      40 autobuild_assistant.register_reply([Agent, None], autobuild_reply)
#      42 with Cache.disk(cache_seed=41) as cache:
# ---> 43     user_proxy.initiate_chat(autobuild_assistant, message=task, max_turns=1)
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/site-packages/autogen/agentchat/conversable_agent.py:1012, in ConversableAgent.initiate_chat(self, recipient, clear_history, silent, cache, max_turns, summary_method, summary_args, message, **kwargs)
#    1010         if msg2send is None:
#    1011             break
# -> 1012         self.send(msg2send, recipient, request_reply=True, silent=silent)
#    1013 else:
#    1014     self._prepare_chat(recipient, clear_history)
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/site-packages/autogen/agentchat/conversable_agent.py:656, in ConversableAgent.send(self, message, recipient, request_reply, silent)
#     654 valid = self._append_oai_message(message, "assistant", recipient)
#     655 if valid:
# --> 656     recipient.receive(message, self, request_reply, silent)
#     657 else:
#     658     raise ValueError(
#     659         "Message can't be converted into a valid ChatCompletion message. Either content or function_call must be provided."
#     660     )
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/site-packages/autogen/agentchat/conversable_agent.py:819, in ConversableAgent.receive(self, message, sender, request_reply, silent)
#     817 if request_reply is False or request_reply is None and self.reply_at_receive[sender] is False:
#     818     return
# --> 819 reply = self.generate_reply(messages=self.chat_messages[sender], sender=sender)
#     820 if reply is not None:
#     821     self.send(reply, sender, silent=silent)
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/site-packages/autogen/agentchat/conversable_agent.py:1973, in ConversableAgent.generate_reply(self, messages, sender, **kwargs)
#    1971     continue
#    1972 if self._match_trigger(reply_func_tuple["trigger"], sender):
# -> 1973     final, reply = reply_func(self, messages=messages, sender=sender, config=reply_func_tuple["config"])
#    1974     if logging_enabled():
#    1975         log_event(
#    1976             self,
#    1977             "reply_func_executed",
#    (...)
#    1981             reply=reply,
#    1982         )
#
# Cell In[23], line 20, in autobuild_reply(recipient, messages, sender, config)
#      18 def autobuild_reply(recipient, messages, sender, config):
#      19     last_msg = messages[-1]["content"]
# ---> 20     builder = agent_builder.AgentBuilder(
#      21         # config_file_or_env="/Users/ekzhu/autogen/OAI_CONFIG_LIST",
#      22         builder_model="gpt-4-turbo",
#      23         agent_model="gpt-4-turbo",
#      24     )
#      25     agent_list, agent_configs = builder.build(
#      26         last_msg, default_llm_config={"config_list": config_list, "cache_seed": None}
#      27     )
#      28     # start nested chat
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/site-packages/autogen/agentchat/contrib/agent_builder.py:200, in AgentBuilder.__init__(self, config_file_or_env, config_file_location, builder_model, agent_model, builder_model_tags, agent_model_tags, max_agents)
#     198 if len(builder_model_tags) != 0:
#     199     builder_filter_dict.update({"tags": builder_model_tags})
# --> 200 builder_config_list = autogen.config_list_from_json(config_file_or_env, filter_dict=builder_filter_dict)
#     201 if len(builder_config_list) == 0:
#     202     raise RuntimeError(
#     203         f"Fail to initialize build manager: {builder_model}{builder_model_tags} does not exist in {config_file_or_env}. "
#     204         f'If you want to change this model, please specify the "builder_model" in the constructor.'
#     205     )
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/site-packages/autogen/oai/openai_utils.py:521, in config_list_from_json(env_or_file, file_location, filter_dict)
#     518     else:
#     519         # Else, it should be a JSON string by itself.
#     520         json_str = env_str
# --> 521     config_list = json.loads(json_str)
#     522 else:
#     523     # The environment variable does not exist.
#     524     # So, `env_or_file` is a filename. We should use the file location.
#     525     if file_location is not None:
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/json/decoder.py:353, in JSONDecoder.raw_decode(self, s, idx)
#     344 """Decode a JSON document from ``s`` (a ``str`` beginning with
#     345 a JSON document) and return a 2-tuple of the Python
#     346 representation and the index in ``s`` where the document ended.
#    (...)
#     350
#     351 """
#     352 try:
# --> 353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
#     355     raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Expecting property name enclosed in double quotes: line 1 column 3 (char 2)
